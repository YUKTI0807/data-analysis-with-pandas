# %% [markdown]
# <a href="https://colab.research.google.com/github/YUKTI0807/data-analysis-with-pandas/blob/main/avocado_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
av = pd.read_csv('/content/drive/MyDrive/PANDAS/avocado.csv')
av.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
print(av.to_string)
# Out:
# <bound method DataFrame.to_string of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
# ...

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
av.describe(percentiles=None, include=None, exclude=None)
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
av.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
av.shape
# Out:
# (18249, 14)

# %%
av.dropna()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
av2 = av.fillna(120)
av2
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
print(av.isnull().sum())
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
print(av.shape[0])
# Out:
# 18249

# %%
print(av.shape[1])
# Out:
# 14

# %%
av[['AveragePrice', 'Total Volume', '4046',	'4225', '4770', 'Total Bags' , 'Small Bags', 	'Large Bags', 	'XLarge Bags']].corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592
# Total Volume    0.963047    0.967238    0.880640     0.747157
# 4046            0.920057    0.925280    0.838645     0.699377
# ...

# %%
av.plot(x='AveragePrice', y='Total Bags', kind='scatter')
plt.title('Average Price vs. Total Bags')
plt.xlabel('Average Price')
plt.ylabel('Total Bags')
plt.show()

# %%
av[['Small Bags', 'Large Bags']].astype({'Small Bags': int, 'Large Bags': int})
# Out:
#        Small Bags  Large Bags
# 0            8603          93
# 1            9408          97
# 2            8042         103
# 3            5677         133
# 4            5986         197
# ...           ...         ...
# 18244       13066         431
# 18245        8940         324
# 18246        9351          42
# 18247       10919          50
# 18248       11988          26
#
# [18249 rows x 2 columns]

# %%
print(av['4046'].rename('x'))
# Out:
# 0        1036.74
# 1         674.28
# 2         794.70
# 3        1132.00
# 4         941.48
#           ...
# 18244    2046.96
# 18245    1191.70
# 18246    1191.92
# 18247    1527.63
# 18248    2894.77
# Name: x, Length: 18249, dtype: float64

# %%
av = av.rename(columns={'4046': 'x'})
print(av.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', 'x', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
av = av.rename(columns={'4225': 'y'})
print(av.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', 'x', 'y', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
av = av.rename(columns={'4770': 'z'})
print(av.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', 'x', 'y', 'z',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
av['AveragePricevolumetwo'] = av['AveragePrice'] * av['Total Volume']
av['AveragePricevolumetwo']
# Out:
# 0         85434.7046
# 1         74083.9230
# 2        109944.8046
# 3         85311.5220
# 4         65330.6880
#             ...
# 18244     27831.9729
# 18245     23748.5484
# 18246     25743.8412
# 18247     31276.0746
# 18248     28333.1196
# Name: AveragePricevolumetwo, Length: 18249, dtype: float64

# %%
av.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', 'x', 'y', 'z',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'AveragePricevolumetwo'],
#       dtype='object')

# %%
av[av['Small Bags'] > 10000]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        x         y  \
# 8               8  2015-11-01          1.02      99811.42  1022.15  87315.57
# 17             17  2015-08-30          1.07     105693.84   689.01  94362.67
# 18             18  2015-08-23          1.34      79992.09   733.16  67933.79
# 19             19  2015-08-16          1.33      80043.78   539.65  68666.01
# 21             21  2015-08-02          1.45      75133.10   509.94  62035.06
# ...           ...         ...           ...           ...      ...       ...
# 18242           5  2018-02-18          1.56      17597.12  1892.05   1928.36
# 18243           6  2018-02-11          1.57      15986.17  1924.28   1368.32
# 18244           7  2018-02-04          1.63      17074.83  2046.96   1529.20
# 18247          10  2018-01-14          1.93      16205.22  1527.63   2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77   2356.13
#
# ...

# %%
av[(av['Small Bags'] > 10000) & (av['Large Bags'] > 10000)]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume          x  \
# 52              0  2015-12-27          0.99     386100.49  292097.36
# 53              1  2015-12-20          1.08     331377.53  251774.15
# 54              2  2015-12-13          0.96     417772.47  324932.28
# 55              3  2015-12-06          1.07     357636.82  283024.01
# 56              4  2015-11-29          0.99     333280.79  250288.65
# ...           ...         ...           ...           ...        ...
# 18232           7  2018-02-04          1.41     283378.47   22474.66
# 18233           8  2018-01-28          1.80     185974.53   22918.40
# 18234           9  2018-01-21          1.83     189317.99   27049.44
# 18235          10  2018-01-14          1.82     207999.67   33869.12
# 18236          11  2018-01-07          1.48     297190.60   34734.97
#
#               y       z  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
av['Date'].value_counts()
# Out:
# Date
# 2015-12-27    108
# 2015-12-20    108
# 2015-12-13    108
# 2015-11-29    108
# 2015-11-22    108
#              ...
# 2018-02-04    108
# 2018-01-07    108
# 2015-12-06    107
# 2017-06-25    107
# 2017-06-18    107
# Name: count, Length: 169, dtype: int64

# %%
av['AveragePrice'].mean()
# Out:
# np.float64(1.405978409775878)

# %%
av['x'].count()
# Out:
# np.int64(18249)

# %%
av['Total Bags'].sum()
# Out:
# np.float64(4373175798.389999)

# %%
av['AveragePrice'].max()
# Out:
# 3.25

# %%
av['AveragePrice'].min()
# Out:
# 0.44

# %%
av['y'].sort_values()
# Out:
# 10532           0.00
# 13385           0.00
# 13346           0.00
# 13345           0.00
# 13338           0.00
#             ...
# 5493     17896391.60
# 2699     18956479.74
# 8366     20328161.55
# 9097     20445501.03
# 5506     20470572.61
# Name: y, Length: 18249, dtype: float64

# %%
av['region'].value_counts()
# Out:
# region
# Albany                 338
# Atlanta                338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# Midsouth               338
# Nashville              338
# NewOrleansMobile       338
# NewYork                338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# ...

# %%
av['type'].nunique()
# Out:
# 2

# %%
av['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
av['x'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
av.groupby('x')['y'].sum().plot(kind="line")
# Out:
# <Axes: xlabel='x'>

# %%
av.groupby('region')['z'].mean().plot(kind="line")
# Out:
# <Axes: xlabel='region'>
